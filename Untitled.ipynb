# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv('data/raw/bank-full.csv', sep=";")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan
# 0   58    management  married   tertiary      no     2143     yes   no  \
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df[['job','age']]
# Out:
#                 job  age
# 0        management   58
# 1        technician   44
# 2      entrepreneur   33
# 3       blue-collar   47
# 4           unknown   33
# ...             ...  ...
# 45206    technician   51
# 45207       retired   71
# 45208       retired   72
# 45209   blue-collar   57
# 45210  entrepreneur   37
#
# [45211 rows x 2 columns]

# %%
for i in df.columns[1:4]:
    if type(i) !='int64':
        fig = plt.figure() # Create matplotlib figure
        ax = fig.add_subplot(111) # Create matplotlib axes
        ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
        width = 0.4
    
        df.query("y == 'no'").groupby(i).size().sort_values(ascending = False).plot(kind='bar', color='red', ax=ax, width=width, position=1)
        df.query("y == 'yes'").groupby(i).size().plot(kind='bar', color='blue', ax=ax2, width=width, position=0)


        ax.set_ylabel('Não Inscritos', color = 'red')
        ax2.set_ylabel('Inscritos', color = 'blue')
        ##plt.legend()
        plt.show()

# %%
df_no_subs = df.query("y == 'no'")

# %%
df_subs = df.query("y == 'yes'")

# %%
plt.figure(figsize=(10, 5))
plt.title("Histograma de idade - Inscritos")
sns.histplot(x=df_subs['age'], label='Age')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.title("Histograma de idade - Não Inscritos")
sns.histplot(x=df_no_subs['age'], label='Age')
plt.show()

# %%
plt.title("Histograma de idade")
plt.hist(df_no_subs.age, label='Não Inscritos', alpha=0.4, color='red')
plt.hist(df_subs.age,label='Inscritos', alpha=1, color='blue') 
plt.legend()
plt.show()

# %%
df['target'] = df['y'].map({"no":0,"yes":1})

# %%
df.groupby(["marital","y"])["y"].count()
# Out:
# marital   y
# divorced  no      4585
#           yes      622
# married   no     24459
#           yes     2755
# single    no     10878
#           yes     1912
# Name: y, dtype: int64

# %%
plt.figure(figsize=(15, 5))
plt.xlabel('job')
plt.ylabel('age')
plt.scatter(df_subs['marital'], df_subs['age'])

# %%
pivot_subs = df_subs.iloc[:,0:2]
pivot_subs
# Out:
#        age         job
# 83      59      admin.
# 86      56      admin.
# 87      41  technician
# 129     55    services
# 168     54      admin.
# ...    ...         ...
# 45204   73     retired
# 45205   25  technician
# 45206   51  technician
# 45207   71     retired
# 45208   72     retired
#
# [5289 rows x 2 columns]

# %%
pivot_subs['value'] = 1

# %%
pivot_subs
# Out:
#        age         job  value
# 83      59      admin.      1
# 86      56      admin.      1
# 87      41  technician      1
# 129     55    services      1
# 168     54      admin.      1
# ...    ...         ...    ...
# 45204   73     retired      1
# 45205   25  technician      1
# 45206   51  technician      1
# 45207   71     retired      1
# 45208   72     retired      1
#
# [5289 rows x 3 columns]

# %%
plt.figure(figsize=(25, 15))

sns.heatmap(pd.pivot_table(pivot_subs, index='job',columns='age', values='value',
               aggfunc='sum', fill_value=0), annot=True, linewidth=.5, cmap='crest')
# Out:
# <Axes: xlabel='age', ylabel='job'>

# %%
df2.head()
# Out:
# job     age
# admin.  21      1
#         22      4
#         23      2
#         24      7
#         25     13
# Name: age, dtype: int64
